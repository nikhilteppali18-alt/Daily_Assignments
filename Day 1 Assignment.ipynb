# %% [markdown]
# Q1. Create variables and store:
#
# Your Name
#
# Age
#
# Height
#
# Is_Student (True/False)
#
# Print all variables with their data types.

# %%
name="Nikhil"
age=25
Height=5.8
Is_Student=True
print(name)
print(age)
print(Height)
print(Is_Student)
print(type(name))
print(type(age))
print(type(Height))
print(type(Is_Student))
# Out:
# Nikhil
# 25
# 5.8
# True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %% [markdown]
# Q2. Take two numbers and perform:
#
# Addition
#
# Subtraction
#
# Multiplication
#
# Division
#
# Modulus

# %%
a=40
b=20
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
# Out:
# 60
# 20
# 800
# 2.0
# 0

# %% [markdown]
# Q3. Convert:
#
# Integer → Float
#
# Float → Integer
#
# Integer → String
#
#
# Print before and after conversion.

# %%
## Before Type conversion 
a=10
print("Before Type Conversion")
print(type(a))

## After Type Conversion
a=10
b=float(a)
print("After Type Conversion")
print(type(b))
# Out:
# Before Type Conversion
# <class 'int'>
# After Type Conversion
# <class 'float'>

# %%
## Before Type conversion 
a=10.2
print("Before Type Conversion")
print(type(a))

## After Type Conversion
a=10.2
b=int(a)
print("After Type Conversion")
print(type(b))
# Out:
# Before Type Conversion
# <class 'float'>
# After Type Conversion
# <class 'int'>

# %% [markdown]
# Q4. Create a list of 5 fruits:
#
# Print first item
#
# Print last item
#
# Add one fruit
#
# Remove one fruit
#
# Reverse list

# %%
List_fruits=["apple","banana","Mango","orange","Cherry"]
print("First Item")
print(List_fruits[0])
# Out:
# First Item
# apple

# %%
print("Last Item")
print(List_fruits[4])
# Out:
# Last Item
# Cherry

# %%
## Add one Fruit
List_fruits.append("Grapes")
print(List_fruits)
# Out:
# ['apple', 'banana', 'Mango', 'orange', 'Cherry', 'Grapes']

# %%
## Remove the value
List_fruits.remove("banana")

# %%
print(List_fruits)
# Out:
# ['apple', 'Mango', 'orange', 'Cherry', 'Grapes']

# %%
## Reverse
List_fruits.reverse()
print(List_fruits)
# Out:
# ['Grapes', 'Cherry', 'orange', 'Mango', 'apple']

# %% [markdown]
# Q5. Given marks=[70,80,90,60,100]
#
# Find:
#
# Maximum
#
# Minimum
#
# Average

# %%
## Maximum
marks=[70,80,90,60,100]
max(marks)
# Out:
# 100

# %%
## Minimum
min(marks)
# Out:
# 60

# %%
## Average
a=sum(marks)/len(marks)
print(a)
# Out:
# 80.0

# %% [markdown]
# Q6. Remove duplicates: x = [1,2,2,3,4,4,5]

# %%
## Remove Duplicates
x=[1,2,2,3,4,4,5]
unique_numbers=list(set(x))
print(unique_numbers)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# Q7. Create a tuple with name,age and course

# %%
a=("nikhil",25,"Data science")
print(a)
print(type(a))
# Out:
# ('nikhil', 25, 'Data science')
# <class 'tuple'>

# %% [markdown]
# Q8. Convert tuple to list and add one element.

# %%
## convert tuple to list
a=(1,2,3,4,5)
b=list(a)
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
## add one element to the List
b.append(6)
print(b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Q9. Create dictionary of a student with name, age, marks, Qualification, Year of Passout Print all keys and values

# %%
student={
    "name":"Nikhil",
    "age" :25,
    "marks":850,
    "Qualification":"B.Tech",
    "Year of Passout":2023
}
print(student)
print(type(student))
# Out:
# {'name': 'Nikhil', 'age': 25, 'marks': 850, 'Qualification': 'B.Tech', 'Year of Passout': 2023}
# <class 'dict'>

# %% [markdown]
# Q10. For the dict in Q9, add new key called City and update marks for 2nd element

# %%
student['city']="Banglore"
student['marks']=900
print(student)
# Out:
# {'name': 'Nikhil', 'age': 25, 'marks': 900, 'Qualification': 'B.Tech', 'Year of Passout': 2023, 'city': 'Banglore'}
