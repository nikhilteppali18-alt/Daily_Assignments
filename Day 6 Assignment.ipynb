# %% [markdown]
# 1. Load the dataset.

# %%
import seaborn as sns

df = sns.load_dataset("mpg")

df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# 2. Display first 10 records.

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
# 5  15.0          8         429.0       198.0    4341          10.0
# 6  14.0          8         454.0       220.0    4354           9.0
# 7  14.0          8         440.0       215.0    4312           8.5
# 8  14.0          8         455.0       225.0    4425          10.0
# 9  15.0          8         390.0       190.0    3850           8.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# ...

# %% [markdown]
# 3. Check shape.

# %%
df.shape
# Out:
# (398, 9)

# %% [markdown]
# 4. Check data types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %% [markdown]
# 5. Check missing values.

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %% [markdown]
# 6. Generate summary statistics.

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# 7. Find average MPG.

# %%
df['mpg'].mean()
# Out:
# np.float64(23.514572864321607)

# %% [markdown]
# 8. Find maximum and minimum horsepower.

# %%
df['horsepower'].max()
# Out:
# np.float64(230.0)

# %%
df['horsepower'].min()
# Out:
# np.float64(46.0)

# %% [markdown]
# 9. Find average weight.

# %%
print(df['weight'].mean())
# Out:
# 2970.424623115578

# %% [markdown]
# 10. Histogram of MPG.

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
import matplotlib.pyplot as plt
plt.hist(df['mpg'],bins=10, edgecolor='black')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.title('Distribution of MPG')
plt.show()

# %%
#Insights:

# i just plotted this Dataset 
# here my Observations are
# MPG has units from 9 to near to 47
# the most of the cars are in the range of 15 to 30 MPG
# At the 15 to 20 MPG there are more cars than the other range of MPG

# %% [markdown]
# 11. Histogram of Horsepower.

# %%
plt.hist(df['horsepower'], bins=10, edgecolor='black')
plt.xlabel('Horsepower')
plt.ylabel('Frequency')
plt.title('Distribution of Horsepower')
plt.show()

# %%
## INSights:
## after visulaizing the above picture
## The horsepower has units from 46 to near to 230
## the most of the cars are in the range of 50 to 150 horsepower
## At the 69 to 100 horsepower there are more cars than the other range of horsepower

# %% [markdown]
# 12. Boxplot of MPG.

# %%
plt.boxplot(df['mpg'])
plt.title('Box Plot of MPG')
plt.ylabel('MPG')
plt.show()

# %%
## INSights:
## I have seen the outliers in the above box plot
## There is one outlier in the above box plot which is near to 47 MPG
## the most of the cars are in the range of 15 to 30 MPG

# %% [markdown]
# 13. Boxplot of Weight.

# %%
plt.boxplot(df['weight'])
plt.title('Box Plot of Weight')
plt.ylabel('Weight')
plt.show()

# %%
## INSights:
## here in this there is no outliers in the above box plot
## the most of the cars are in the range of 2000 to 4000 weight

# %% [markdown]
# 14. Countplot of Cylinders.

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.countplot(x='cylinders', data=df)
plt.show()

# %%
## INSights:
## after visulaizing the above picture
## when the car has 4 cylinders the car count is  to likely near to 200
## when the car has 3 cylinders the car count is  to likely near to 10
## when the car has 6 cylinders the car count is  to likely near to 100
## when the car has 8 cylinders the car count is  to likely near to 50
## Final Observation is the most of the cars are 4 cylinders and the least of the cars are 3 cylinders

# %% [markdown]
# 15. Calculate correlation matrix.

# %%
corr_matrix = df.corr(numeric_only=True)

corr_matrix
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %% [markdown]
# 16. Draw heatmap.

# %%
corr_matrix = df.corr(numeric_only=True)

sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
## INSights:
## after visulaizing the above picture
## the correlation between the weight and the horsepower is 0.86 which is a strong positive correlation
## the correlation between the weight and the mpg is -0.83 which is a strong negative correlation
## the correlation between the horsepower and the mpg is -0.78 which is a strong negative correlation

# %% [markdown]
# 17. Which feature is most positively correlated with MPG?

# %%
corr = df.corr(numeric_only=True)["mpg"].sort_values(ascending=False)

print(corr)
print("Most positively correlated feature:", corr.index[1])
## Here in this The most positively correlated feature with the "MPG" is "Model Year"
# Out:
# mpg             1.000000
# model_year      0.579267
# acceleration    0.420289
# cylinders      -0.775396
# horsepower     -0.778427
# displacement   -0.804203
# weight         -0.831741
# Name: mpg, dtype: float64
# Most positively correlated feature: model_year

# %% [markdown]
# 18. Which feature is most negatively correlated with MPG?

# %%
corr = df.corr(numeric_only=True)["mpg"].sort_values()

print(corr)
print("Most negatively correlated feature:", corr.index[0])
## Here in this The most negatively correlated feature with the "MPG" is "Weight"
# Out:
# weight         -0.831741
# displacement   -0.804203
# horsepower     -0.778427
# cylinders      -0.775396
# acceleration    0.420289
# model_year      0.579267
# mpg             1.000000
# Name: mpg, dtype: float64
# Most negatively correlated feature: weight

# %% [markdown]
# 19. Scatter plot:
# Weight vs MPG

# %%
plt.scatter(df['weight'], df['mpg'])
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.title('Scatter Plot of Weight vs MPG')
plt.show()

# %%
## INSights:
## Here in the above plot
## When the weight of the car is increasing the MPG is decreasing
## and when the weight of the car is decreasing the MPG is increasing

# %% [markdown]
# 20. Scatter plot:
# Horsepower vs MPG

# %%
plt.scatter(df['horsepower'], df['mpg'])
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.title('Scatter Plot of Horsepower vs MPG')
plt.show()

# %%
## INSights:
## after visulaizing the above picture
## The more the horsepower of the car is increasing the MPG is decreasing
## and the more the horsepower of the car is decreasing the MPG is increasing

# %% [markdown]
# 21. Scatter plot:
# Displacement vs MPG

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
plt.scatter(df['displacement'],df['mpg'])
plt.xlabel('Displacement')
plt.ylabel('MPG')
plt.title('Scatter Plot of Displacement vs MPG')
plt.show()

# %%
## INSights:
## after observing the above plot
## The more the displacement of the car is increasing the MPG is decreasing
##There are some cars which have more displacement but they have more MPG which is not common in the above plot

# %% [markdown]
# 22. Detect outliers in Horsepower.

# %%
plt.boxplot(df['horsepower'])
plt.xlabel('Horsepower')
plt.title('Box Plot of Horsepower')
plt.show()

# %%
## INSights:
##The above plot shows
## There are no outliers in the above box plot of horsepower

# %% [markdown]
# 23. Detect outliers in Weight.

# %%
plt.boxplot(df['weight'])
plt.xlabel('Weight')
plt.title('Box Plot of Weight')
plt.show()

# %%
## INSights:
## There are no outliers in the above box plot of weight

# %% [markdown]
# 24. Detect outliers in MPG using IQR.

# %%
Q1 = df["mpg"].quantile(0.25)
Q3 = df["mpg"].quantile(0.75)

print("Q1:", Q1)
print("Q3:", Q3)
# Out:
# Q1: 17.5
# Q3: 29.0

# %%
IQR = Q3 - Q1

print("IQR:", IQR)
# Out:
# IQR: 11.5

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: 0.25
# Upper Bound: 46.25

# %%
outliers = df[(df["mpg"] < lower_bound) | (df["mpg"] > upper_bound)]

outliers
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0        65.0    2110          17.9
#
#      model_year origin       name
# 322          80  japan  mazda glc

# %%
print("Number of Outliers:", len(outliers))
# Out:
# Number of Outliers: 1

# %% [markdown]
# 25. Which cars appear most fuel efficient?

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
top_cars = df.sort_values(by="mpg", ascending=False)

print(top_cars[["name", "mpg"]].head(10))
# Out:
#                                 name   mpg
# 322                        mazda glc  46.6
# 329              honda civic 1500 gl  44.6
# 325             vw rabbit c (diesel)  44.3
# 394                        vw pickup  44.0
# 326               vw dasher (diesel)  43.4
# 244  volkswagen rabbit custom diesel  43.1
# 309                        vw rabbit  41.5
# 330             renault lecar deluxe  40.9
# 324                       datsun 210  40.8
# 247                   datsun b210 gx  39.4

# %%
most_efficient = df.loc[df["mpg"].idxmax()]

print(most_efficient["name"])
print(most_efficient["mpg"])
# Out:
# mazda glc
# 46.6

# %% [markdown]
# 26. Does higher weight reduce MPG?

# %%
sns.scatterplot(x='weight', y='mpg', data=df)
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.title('Scatter Plot of Weight vs MPG')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Weight vs MPG')

# %%
## INSights:
## after visulaizing the above picture
## My Answer is Yes
## the higher weight like near to 5000 the MPG will be reducing to near to 10
## and the lower weight like near to 2000 the MPG will be increasing to near to 40

# %% [markdown]
# 27. Does horsepower impact MPG?

# %%
sns.scatterplot(x='horsepower', y='mpg', data=df)
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.title('Scatter Plot of Horsepower vs MPG')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Horsepower vs MPG')

# %%
## INSights:
## after visulaizing the above picture
## My Answer is Yes
## the higher horsepower like near to 200 the MPG will be reducing to near to 10
## and the lower horsepower like near to 50 the MPG will be increasing to near to 40

# %% [markdown]
# 28. Write 5 insights from the dataset.

# %%
## INSights:
## After carefully observing the overall dataset and the above some of the plots
## First One there is one outlier present in the above dataset
## Most of the cars are in the range of 15 to 30 MPG
## The most of the cars are in the range of 50 to 150 horsepower
## Some of the few cars have high horsepower
## most of the cars have weight in the range of 2000 to 4000
